# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
ls=[["name","roll","marks"],["Akshir",114,7.88],["Numan","I dont ",8.6],["Numan","I  know",87.6],["Numan"," sddont know",8.6],["Numan","I dohjhgnt know",8.6],["Numan","I donow",8.6],["Numan","I dont ow",8.6],["Numan","I dont k",8.6],["Numan","I f know",8.6]]
import csv
with open("marks.csv","w") as f:
     a=csv.writer(f)
    
     for i in ls:
            a.writerow(i)

# %%
df_withoud_head_col=pd.read_csv("marks.csv",header=None)
df=pd.read_csv("marks.csv")
#making a file

# %%
df
# Out:
#      name             roll  marks
# 0  Akshir              114   7.88
# 1   Numan          I dont    8.60
# 2   Numan          I  know  87.60
# 3   Numan      sddont know   8.60
# 4   Numan  I dohjhgnt know   8.60
# 5   Numan          I donow   8.60
# 6   Numan        I dont ow   8.60
# 7   Numan         I dont k   8.60
# 8   Numan         I f know   8.60

# %%
df.head() # by default it is taking 5 head data
# Out:
#      name             roll  marks
# 0  Akshir              114   7.88
# 1   Numan          I dont    8.60
# 2   Numan          I  know  87.60
# 3   Numan      sddont know   8.60
# 4   Numan  I dohjhgnt know   8.60

# %%
df.head(3) # we can take var
# Out:
#      name     roll  marks
# 0  Akshir      114   7.88
# 1   Numan  I dont    8.60
# 2   Numan  I  know  87.60

# %%
df.tail() # by default it is takin 5 head
# Out:
#     name             roll  marks
# 4  Numan  I dohjhgnt know    8.6
# 5  Numan          I donow    8.6
# 6  Numan        I dont ow    8.6
# 7  Numan         I dont k    8.6
# 8  Numan         I f know    8.6

# %%
df.tail(3)# by default it is takin 5 head
# Out:
#     name       roll  marks
# 6  Numan  I dont ow    8.6
# 7  Numan   I dont k    8.6
# 8  Numan   I f know    8.6

# %%
type(df) #DataFrame is tabular form of data
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['name', 'roll', 'marks'], dtype='object')

# %%
list(df.columns)
# Out:
# ['name', 'roll', 'marks']

# %%
df["name"] # taking out series of data of specific column
# Out:
# 0    Akshir
# 1     Numan
# 2     Numan
# 3     Numan
# 4     Numan
# 5     Numan
# 6     Numan
# 7     Numan
# 8     Numan
# Name: name, dtype: object

# %%
type(df["name"])
# Out:
# pandas.core.series.Series

# %%
df[['name']]
# Out:
#      name
# 0  Akshir
# 1   Numan
# 2   Numan
# 3   Numan
# 4   Numan
# 5   Numan
# 6   Numan
# 7   Numan
# 8   Numan

# %%
type(df[['name']])
# Out:
# pandas.core.frame.DataFrame

# %%
df["name","roll"] #cant pass multiple columns for that we need to pass a list as shown in very next line
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/conda/lib/python3.10/site-packages/pandas/core/indexes/base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File /opt/conda/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File /opt/conda/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('name', 'roll')
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df[["name","roll"]]
# Out:
#      name             roll
# 0  Akshir              114
# 1   Numan          I dont
# 2   Numan          I  know
# 3   Numan      sddont know
# 4   Numan  I dohjhgnt know
# 5   Numan          I donow
# 6   Numan        I dont ow
# 7   Numan         I dont k
# 8   Numan         I f know

# %%
df.dtypes  #data types of columns
# Out:
# name      object
# roll      object
# marks    float64
# dtype: object

# %%
df1=pd.read_excel("A.xlsx")  #reading excel file

# %%
df1
# Out:
#      NAME  EMPID  SALARY
# 0     ABC      1   10000
# 1     XYZ      2   10000
# 2     PQR      3   10000
# 3     STU      4   10000
# 4    DSDS      5   10000
# 5    CVSD      6   10000
# 6    DCSD      7   10000
# 7     DCX      8   10000
# 8   DSCSD      9   10000
# 9   SDCXC     10   10000
# 10    DCX     11   10000
# 11    C X     12   10000
# 12    ABC     13   10000
# 13    SFS     14   10000
# 14     GD     15   10000
# 15     GD     16   10000
# 16     SG     17   10000
# 17     GD     18   10000
# 18      F     19   10000
# 19  hskjh     20   10000

# %%
df1.dtypes
# Out:
# NAME      object
# EMPID      int64
# SALARY     int64
# dtype: object

# %%
df1.columns  # retrieving all the columns name
# Out:
# Index(['NAME', 'EMPID', 'SALARY'], dtype='object')

# %%
df1["NAME"]
# Out:
# 0       ABC
# 1       XYZ
# 2       PQR
# 3       STU
# 4      DSDS
# 5      CVSD
# 6      DCSD
# 7       DCX
# 8     DSCSD
# 9     SDCXC
# 10      DCX
# 11      C X
# 12      ABC
# 13      SFS
# 14       GD
# 15       GD
# 16       SG
# 17       GD
# 18        F
# 19    hskjh
# Name: NAME, dtype: object

# %%
df1[["NAME","EMPID"]]
# Out:
#      NAME  EMPID
# 0     ABC      1
# 1     XYZ      2
# 2     PQR      3
# 3     STU      4
# 4    DSDS      5
# 5    CVSD      6
# 6    DCSD      7
# 7     DCX      8
# 8   DSCSD      9
# 9   SDCXC     10
# 10    DCX     11
# 11    C X     12
# 12    ABC     13
# 13    SFS     14
# 14     GD     15
# 15     GD     16
# 16     SG     17
# 17     GD     18
# 18      F     19
# 19  hskjh     20

# %%
df2=pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")  #retrieving from link

# %%
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df2.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df2[["PassengerId","Name"]]
# Out:
#      PassengerId                                               Name
# 0              1                            Braund, Mr. Owen Harris
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3                             Heikkinen, Miss. Laina
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5                           Allen, Mr. William Henry
# ..           ...                                                ...
# 886          887                              Montvila, Rev. Juozas
# 887          888                       Graham, Miss. Margaret Edith
# 888          889           Johnston, Miss. Catherine Helen "Carrie"
# 889          890                              Behr, Mr. Karl Howell
# 890          891                                Dooley, Mr. Patrick
#
# [891 rows x 2 columns]

# %%
df2.to_csv('file1.csv')

# %%
pip install lxml
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import lxml
df3=pd.read_html("https://www.basketball-reference.com/leagues/NBA_2015_totals.html") # taking data from website with tables in the form of list

# %%
df3[0] # taking out 1st element of list
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
dfx=df3[0].head(24)  # slicing the table as we only need 24 elements

# %%
dfx
# Out:
#     Rk                 Player Pos Age   Tm   G  GS    MP   FG   FGA  ...  \
# 0    1             Quincy Acy  PF  24  NYK  68  22  1287  152   331  ...
# 1    2           Jordan Adams  SG  20  MEM  30   0   248   35    86  ...
# 2    3           Steven Adams   C  21  OKC  70  67  1771  217   399  ...
# 3    4            Jeff Adrien  PF  28  MIN  17   0   215   19    44  ...
# 4    5          Arron Afflalo  SG  29  TOT  78  72  2502  375   884  ...
# 5    5          Arron Afflalo  SG  29  DEN  53  53  1750  281   657  ...
# 6    5          Arron Afflalo  SG  29  POR  25  19   752   94   227  ...
# 7    6          Alexis Ajinça   C  26  NOP  68   8   957  181   329  ...
# 8    7         Furkan Aldemir  PF  23  PHI  41   9   540   40    78  ...
# 9    8           Cole Aldrich   C  26  NYK  61  16   976  144   301  ...
# 10   9      LaMarcus Aldridge  PF  29  POR  71  71  2512  659  1415  ...
# 11  10            Lavoy Allen   C  25  IND  63   0  1070  141   299  ...
# ...

# %%
dfx.to_csv("2nd_link.csv") # storing in a file into our local machine to see large csv file data

# %%
dfx.dtypes
# Out:
# Rk        object
# Player    object
# Pos       object
# Age       object
# Tm        object
# G         object
# GS        object
# MP        object
# FG        object
# FGA       object
# FG%       object
# 3P        object
# 3PA       object
# 3P%       object
# 2P        object
# 2PA       object
# 2P%       object
# eFG%      object
# FT        object
# FTA       object
# FT%       object
# ORB       object
# DRB       object
# TRB       object
# AST       object
# STL       object
# BLK       object
# TOV       object
# PF        object
# PTS       object
# dtype: object

# %%
df3[0].to_csv("2nd_link_complete.csv",index=False)  # storing whole table data in a file into our local machine to see large csv file data

# %%
#-----------------------------------Thank You----------------------------------------------------#
